# %% [markdown]
# ## **Introduction**

# %%
####### tools_to_install_urls.txt ###########

# UV installation link :
# https://docs.astral.sh/uv/getting-started/installation/#standalone-installer

# VS code installation link : 
# https://code.visualstudio.com/download

# %% [markdown]
# ## **2_installation_variables_dataType_operators_1701**

# %% [markdown]
# I can see all 9 pages clearly. Let me build a comprehensive PDF for this Python-1 session.Your Python-1 notes PDF is ready! Here's everything packed in across **8 pages**:
#
# **📄 Page-by-page breakdown**
#
# **Cover** — Date, session title, topic tags, color-coded metadata
#
# **Page 1 — Tools & Environment**
# - Full tool stack diagram (Hardware → OS → Python → UV → VS Code) as layered boxes
# - UV command flow diagram (install, pin, venv, run)
# - VS Code + Virtual Environments side-by-side
# - Complete UV command reference with inline comments
#
# **Page 2 — File Types**
# - File extensions diagram: `.mp3/.wav` → `.mp4` → `.txt` → `.py` → `.ipynb`
# - Tech vs Non-Tech learning path comparison
# - `.ipynb` notebook structure explained
#
# **Page 3 — Python & RAM**
# - RAM grid diagram showing R2C2 address model (how `a=12` works in memory)
# - Python execution model: install→HDD, run→RAM
# - Variables as named RAM addresses
#
# **Page 4 — Data Types**
# - All 4 types: int, float, string, bool with memory cell counts
# - `12 ≠ 12.0` — visual comparison (4 cells vs 8 cells)
# - Type casting diagram: all 6 conversion combinations
#
# **Page 5 — Operators**
# - All 5 operator types in a structured diagram
# - Complete code reference for all 30+ operators with examples
#
# **Page 6 — Assignments + Mind Map**
# - Assignment 1 folder structure (Data_Science/Day-1/Day-2...)
# - Full session mind map (radial diagram connecting all topics)
#
# **Page 7 — Quick Reference Table**
# - 25 rows covering all commands, syntax, and notes

# %%
## Topics Covered 
1. GitHub Copilot Chat
2. cyberpunk

# %%
### TOPIC ##########
## Variables: To store something in a programming lanaguge we use variables

## functions 
# 1. type()
# 2. id()   ==> Address of variable
# 3. print() 

## comemnts and multiline comments
## Data Types: int, str, float 
## Nming conventions

# Naming convention
    # - variable names can only contain letters, digits and underscore (_)
    #     - bmi, person0, person_1, _person, id_1
    # - it should not start with a digit 
    # - variable names are case sensitive : hello, Hello, heLlo
    # - avoid using python keywords : type, print, id, if, else, for

    # # Flow of python

    # In python, execution happens from top to bottom and right to left

    # in case of paranthesis, from inner brackets to outer

### Few more data types : boolean or bool # True / False 
## typecasting:  If we have int and we want to make it float, we use type casting
  # 1. int()
  # 2. float()

## Operators - 1
 # Airthmetic Operators ( + , - , // , / , %)

# %% [markdown]
# ## **3.STRING OPERATION**

# %% [markdown]
# I can see all 9 pages clearly. Let me build the comprehensive PDF for Python-II session.Your Python-II notes PDF is ready! Here's what's packed inside across **9 pages**:
#
# **📄 Cover** — Date, session title, all topic tags in cyan theme
#
# **Page 1 — String Properties & OOP Concepts**
# - Class vs Method vs Function diagram (House/Car/str analogy)
# - `type()`, `id()`, `print()` as standalone functions
# - Why `int.strip()` gives an error — methods belong to their class
#
# **Page 2 — String Methods**
# - All 8 key string methods table (strip, lstrip, rstrip, upper, lower, replace, split, find)
# - Real-world demo: Google Form data normalization (`"Data"`, `"data"`, `" data"`)
# - Age-from-CSV use case: `int(' 27 '.strip()) → 27`
#
# **Page 3 — Relational Operators**
# - All 6 comparison operators with visual layout + results
# - `True→1`, `False→0` relationship
# - String comparison: `"Data" == "Data "` → False
#
# **Page 4 — Assignment Operators**
# - All 8 compound assignment operators (`+=`, `-=`, `*=`, etc.)
# - `=` vs `==` distinction highlighted in red
#
# **Page 5 — Logical Operators + Truth Tables**
# - Four side-by-side truth tables: AND, OR, NOT, XOR
# - Code examples with combined conditions
#
# **Page 6 — Bitwise Operators**
# - Binary number system (2², 2¹, 2⁰ → 4,2,1)
# - `&`, `|`, `^`, `~`, `<<`, `>>` with binary worked examples
#
# **Page 7 — Control Flow (if/else + elif)**
# - Diamond flowchart diagram
# - Apple store task + WiFi app task
# - Indentation rule: 1 Tab = 4 spaces
#
# **Page 8 — Non-Primitive Types + Lists**
# - Primitive vs Non-Primitive comparison
# - List structure diagram with index labels
# - Building entry register example (nested list)
#
# **Page 9 — Quick Reference** — 33-row table + key takeaways

# %%
## non primitive data type :
# 
list_1 = [1,2,3,4,5] 
for item in list_1:
    print(item * 2)

## Yaar coding is so important to do , 
## do code as much as possible 

name = ""
age = 0 
salary = 0.0 

for _ in range(100):
    name = "get_name"
    age = "get_age"
    salary = "get_salary"
    
    person_1 = [name, age, salary, ]

register = []
resister.append(person_1)

# %%
## Topics 
'''
* Primary Data type: 
 --> primitive data type 
  * int 
  * float 
  * str 
  * boolean

* Non Primitive Data Type 
  * list 
  * tuple
  * set 
  * dict --> dictionary
'''

## String Operation: 
'''
 - strip() 
 - lstrip()
 - rstrip()
'''

### Operators
'''
 1. relational 
 2. Assignment Operator
 3. Logical Opeartor
 4. Bitwise Operators

'''
## Conditional Statement or Control FLOW 
'''
 1. IF 
 2. IF-ELSE
 3. IF-ELIF-ELS
'''

## More data types 
'''
 1. list 
'''

# %% [markdown]
# ## **4. Input/Output control flow**

# %%
### TOPICS COVERED #######
# output : 
 ## print()
 ## print( , end = "")

## input ==> input()
## Control Flow 
## range(starts_with, ends_with+1, step_size)

# %% [markdown]
# ## **5_NonPrimitive_ListDictSetTuple_2401**

# %%
### TOPIC COvered ####
# Non Primitve Data types : 
  ## 1. List   [ append(), pop(): removeFromBeginneing, , remove(element), insert(index, element)]
  ## 2. Dictionary ==> [ get() , keys() , values() ]
  ## 3. tuple ===> [ tuple(),  ]
  ## 4. set ===>   [ add() , ]

# len()
# sorted(<>, reverse=True/False )

# %%
#### Python Discussion on cenral resource - Non primitive data types

# %% [markdown]
# ## **6_string_while_controlflow_function_2501**

# %%
## Python - String Methods - Loops - Functions -- Functions Arguments

# %%
## Topic Covered 
## 1. String Methods
   ## upper()/lower() , title(), capitalize(), swapcase()
   ## strip(), split(), find()
   ## join() 

## 2. While Loop 
## 3. Control Flow  [ Continue, break]
## 4. Functions

# %% [markdown]
# ## **DAY7: Scope_functionArgs_osLib_fileOpeartion**

# %%
##### TopiC Covered ############
# 1. Scope of variable 
   # Local 
   # Global

# 2. Function Arguments
  # *args => arguments ==> tuple
  # **kwargs => keyword argument ==> dictionary

# 3. INtermediate Python 
  # library : os 
  # getcwd()
  # listdir()
  # os.path.join(<>, )

# 4. File Operation 
  ## read file ( 
     ## f = open("dummy.tx")
     ## lines = f.readlines()
     ## line = f.readline()

  ## update file 
  ## append ore content to file 
  ## close file

# %% [markdown]
# ## **DAY8:fileOperations_ExceptionHandling**

# %%
# day8_fileOperations_ExceptionHandling

# %%
## Topic Coverd ########
# 1. File Mode : 
  ## r, w, a 
  ## r+ ( Read & Write )
  ## a+ (read & append )
  ## w+ (write & read)

# 2. File Operations 
  ## f.tell()
  ## all_content = f.read()
  ## f.write(<>)
  ## f.seek()

## Exception Handing ####
