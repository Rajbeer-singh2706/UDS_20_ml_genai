# %%
print("ALLOKAY")

# %% [markdown]
# ## **FEature ENGINNERING**

# %%
print("ALLOKAY")

# %% [markdown]
# ## **DAY2: 25-APR**

# %% [markdown]
# ## **DAY 3: 26-APR**

# %%
"OKAY"

# y = mx + c

# %%
# How to u usually do revision
